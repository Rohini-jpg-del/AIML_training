# %%
import numpy as np
import matplotlib.pyplot as plt
image=np.full((160,160,3),250,dtype='uint8')
image[40:100,40:50]=[0,0,255]
cv2.imshow('image',image)
cv2.imwrite('image.jpg',image)
cv2.waitkey(5000)
cv2.destroyAllWinndows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
#       3 image=np.full((160,160,3),250,dtype='uint8')
#       4 image[40:100,40:50]=[0,0,255]
# ----> 5 cv2.imshow('image',image)
#       6 cv2.imwrite('image.jpg',image)
#       7 cv2.waitkey(5000)
#       8 cv2.destroyAllWinndows()
#
# NameError: name 'cv2' is not defined
